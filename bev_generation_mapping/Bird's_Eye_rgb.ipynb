# %% [markdown]
# ## This code was modified from https://github.com/MankaranSingh/Auto-Birds-Eye
# See https://medium.com/asap-report/from-semantic-segmentation-to-semantic-birds-eye-view-in-the-carla-simulator-1e636741af3f for info about the 4-camera dataset used here
#
# Before running this notebook, ensure that:
# 1. "Autonomous Driving" folder (https://drive.google.com/drive/u/0/folders/1GG1uDsiTSbkGYJoN4YJJ7LaQx2F8uJB8) is shared with you
# 2. create a shortcut to "Autonomous Driving" folder in your "My Drive"

# %% [markdown]
# ## Initialize

# %%
from google.colab import drive
bev_folder = './drive/My Drive/Autonomous Driving/bev_generation_mapping/'
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from keras.utils import to_categorical

import time
import keras.backend as K
from keras import Input, Model
from keras.layers import Convolution2D, LeakyReLU, BatchNormalization, Conv2D, UpSampling2D, Subtract, Concatenate, Softmax, Dropout, Activation,MaxPooling2D, Flatten, Dense, Lambda, Reshape, concatenate, ZeroPadding2D, Cropping2D
from keras.optimizers import Adam
import tensorflow as tf
from PIL import Image

# %%
# mapping from "original" 13-label dataset to "simplified" 3-label dataset
LABELS_MAPPING = {
    0:  0,  # None         -> Nonroad
    1:  0,  # Buildings    -> Nonroad
    2:  0,  # Fences       -> Nonroad
    3:  0,  # Other        -> Nonroad
    4:  2,  # Pedestrians  -> Obstacles
    5:  0,  # Poles        -> Nonroad
    6:  1,  # RoadLines    -> Roads
    7:  1,  # Roads        -> Roads
    8:  0,  # Sidewalks    -> Nonroad
    9:  0,  # Vegetation   -> Nonroad
    10: 2,  # Vehicles     -> Obstacles
    11: 0,  # Walls        -> Nonroad
    12: 0,  # TrafficSigns -> Nonroad
}

# 3-label "RGB" dataset labels
LABELS = {
    0: 'Nonroad',       # colored red
    1: 'Road',          # colored green
    2: 'Obstacles',     # colored blue
}

# switch red and green for final image (request by James)
RG_MAPPING = {
    0: 1,
    1: 0,
    2: 2
}

# %%
# This dataset has 3 labels
# !cp "/content/drive/MyDrive/Autonomous Driving/bev_generation_mapping/data_rgb/data_rgb.zip" .
# !unzip -qo 'data_rgb.zip'

# %%
# This dataset has 13 labels
# !gdown "https://drive.google.com/uc?id=1x0JdeA2Mo_QvYIJDHMfempoy2R675gMi" -O "birds_eye_data.zip"
# !unzip -qo 'birds_eye_data.zip'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1x0JdeA2Mo_QvYIJDHMfempoy2R675gMi
# To: /content/birds_eye_data.zip
# 100% 584M/584M [00:19<00:00, 30.7MB/s]

# %%
import os
print(len(os.listdir('data_rgb/front')))
print(len(os.listdir('data_rgb/top')))
# Out:
# 46000
# 46000

# %% [markdown]
# ## Reloading Data

# %%
# front: (all colors), (RGB)
# top:   (all colors), (RGB)

rows = 2
columns = 2

def plot_cameras(sequence_number):

    fig=plt.figure(figsize=(20, 20))
    imgs = []
    cameras = ['front','top']

    cnt = 0
    for cam in cameras:
        # all colors
        sample = np.load(f"./data/{cam}/{sequence_number}.npy")
        fig.add_subplot(rows, columns, cnt+1)
        plt.imshow(sample, cmap='gist_stern')
        cnt += 1

        # reduced to rgb
        sample = np.load(f"./data_rgb/{cam}/{sequence_number}.npy")
        sample_rgb = np.empty([sample.shape[0], sample.shape[1], 3])
        sample = np.vectorize(RG_MAPPING.get)(sample)

        for i in range(3):
            sample_rgb[:, :, i] = np.where(np.isin(sample, i), 1, 0)
        fig.add_subplot(rows, columns, cnt+1)
        plt.imshow(sample_rgb)
        cnt += 1

    plt.show()

# %%
N = 1002
# print(np.load(f'./data_rgb/front/{N}.npy').shape)
# print(np.load(f'./data_rgb/top/{N}.npy').shape)
plot_cameras(N)

# %%
import os
def get_paths(val_size=5000):
    img_paths = []

    for i in range(len(os.listdir('./data_rgb/top'))):
        path = f'{i}.npy'
        img_paths.append(path)

    return pd.DataFrame({'path':img_paths[:-val_size]}), pd.DataFrame({'path':img_paths[-val_size:]})

# %%
img_paths_train, img_paths_val = get_paths() # 41k training imgs + 5k validation imgs = 46k
img_paths_train
# Out:
#             path
# 0          0.npy
# 1          1.npy
# 2          2.npy
# 3          3.npy
# 4          4.npy
# ...          ...
# 40995  40995.npy
# 40996  40996.npy
# 40997  40997.npy
# 40998  40998.npy
# 40999  40999.npy
#
# [41000 rows x 1 columns]

# %% [markdown]
# ## Setting up Data Generators

# %%
# convert RGB image to Nonroad-Road-Obstacles image
# for each channel (eg. Obstacles): 1=has that label, 0=doesn't have that label
def img_to_categorical(img, needed_labels):
    cat = np.empty((img.shape[0], img.shape[1], len(needed_labels)))
    for channel, label in enumerate(needed_labels):
        cat[:, :, channel] = np.where(np.isin(img, label), 1, 0)
    return cat

def categorical_to_img(cat):  
    img = np.argmax(cat, axis=-1)
    return img

# Given "image" (2D matrix of labels), plot the corresponding RGB image
def plot_rgb(img):
    rgb = np.empty([img.shape[0], img.shape[1], 3])
    for i in range(3):
        rgb[:, :, i] = np.where(np.isin(img, i), 1, 0)
    plt.imshow(rgb)

needed_labels = [0, 1, 2]

# %%
from tensorflow.keras.utils import Sequence

class DataGenerator2D(Sequence):
    """Generates data for Keras
    Sequence based data generator. Suitable for building data generator for training and prediction.
    """
    def __init__(self, img_paths, base_path, to_fit=True, batch_size=32, shuffle=True, needed_classes = []):
    
        self.img_paths = img_paths.copy()
        self.base_path = base_path
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.needed_classes = needed_classes
        self.on_epoch_end()
    
    def __len__(self):
        """Denotes the number of batches per epoch
        :return: number of batches per epoch
        """
        return int(len(self.img_paths) // self.batch_size)

    def __getitem__(self, index):
        """Generate one batch of data
        :param index: index of the batch
        :return: X and y when fitting. X only when predicting
        """
        # Generate indexes of the batch
        current_indexes = list(range(index * self.batch_size, (index + 1) * self.batch_size))
        img_paths_temp = self.img_paths[current_indexes]

        # Generate data
        X = self._generate_X(img_paths_temp)

        if self.to_fit:
            y = self._generate_y(img_paths_temp)
            return X, y
        else:
            return X

    def on_epoch_end(self):
        """Updates indexes after each epoch
        """
        if self.shuffle == True:
            indices = np.arange(len(self.img_paths))
            np.random.shuffle(indices)
            self.img_paths = self.img_paths[indices]
            self.img_paths.reset_index(drop=True, inplace=True)


    def _generate_X(self, img_paths_temp):
        """Generates data containing batch_size images
        :param img_paths_temp: list of label ids to load
        :return: batch of images
        """
        # Initialization
        X = []

        # Generate data
        for idx, path in zip(img_paths_temp.index, img_paths_temp):
            # Store sample
            img = self._load_image(path, front=True)
            X.append(img)

        return np.array(X)

    def _generate_y(self, img_paths_temp):

        y = []

        for idx, path in zip(img_paths_temp.index, img_paths_temp):
            # Store sample
            img = self._load_image(path, front=False)
            y.append(img) 
        return np.array(y)

    def _load_image(self, image_path, front=True):
        if front:
            img_dir =  '/front/'
        else:
            img_dir =  '/top/'
        img = np.load(self.base_path + img_dir + image_path)
        img = img[::2, ::2]                                         # Downsampling image by factor of 2
        img = np.vectorize(RG_MAPPING.get)(img)                     # Swap red and green

        if not front:
            img = img[3:(img.shape[0]//2)]                          # Cut off the top half
            img = np.rot90(img, 3)                                  # Rotate so car is on the left
            img = img[2:-2, 8:]                                     # Crop Image to make dimensions divisible by 8 
                                                                    # Crop off the hood of the car as well
            img = cv2.resize(img.astype('float'), dsize=(72, 80))   # Resize to 80 x 72 x 3 image (model output)
            img = img_to_categorical(img, self.needed_classes)

        else:
            img = img[2:-18, 3:-3]                                  # Crop Image to make dimensions divisible by 8 
                                                                    # Crop off the hood of the car as well
            img = img_to_categorical(img, self.needed_classes)

        return img

# %%
train_generator = DataGenerator2D(img_paths_train['path'], './data_rgb', batch_size=32, shuffle=True, needed_classes=needed_labels)
val_generator = DataGenerator2D(img_paths_val['path'], './data_rgb', batch_size=1, shuffle=False, needed_classes=needed_labels)

# %%
# Test the generator
X, y = train_generator.__getitem__(0)
print(X.shape, y.shape)

input_shape = X.shape[1:]
print(input_shape)
# Out:
# (32, 80, 144, 3) (32, 80, 72, 3)
# (80, 144, 3)

# %%
fig=plt.figure(figsize=(17, 17))
columns = 5
rows = 1
for i in range(1, columns*rows + 1):
    img = X[i-1]
    fig.add_subplot(rows, columns, i)
    # plt.imshow(categorical_to_img(img), cmap='gist_stern', vmin=0, vmax=len(needed_labels)-1)
    plot_rgb(categorical_to_img(img))
plt.show()

# %%
fig=plt.figure(figsize=(17, 17))
columns = 5
rows = 1
for i in range(1, columns*rows + 1):
    img = y[i-1]
    fig.add_subplot(rows, columns, i)
    # plt.imshow(np.rot90(categorical_to_img(img), 3), cmap='gist_stern', vmin=0, vmax=len(needed_labels)-1)
    plot_rgb(categorical_to_img(img))
plt.show()

# %%
import time
import keras.backend as K
from keras import Input, Model
from keras.layers import Convolution2D, LeakyReLU, BatchNormalization, UpSampling2D, Subtract, Concatenate, Softmax, Dropout, Activation,MaxPooling2D, Flatten, Dense, Lambda, Reshape, concatenate, ZeroPadding2D, Cropping2D
from keras.optimizers import Adam
from keras import Sequential

# %%
# UNet Generator is worse!

# def build_unet_generator(needed_labels):

#   """
#   Create U-Net Generator using the hyperparameter values defined
#   below
#   """

#   kernel_size = [8, 6, 4, 6, 6, 8]
#   strides = 2
#   leakyrelu_alpha = 0.2
#   upsampling_size = 2
#   output_channels = len(needed_labels)
#   input_shape = (96, 144, len(needed_labels))

#   # Setting up the input
#   input_layer = Input(shape=input_shape)

#   # Encoder Network

#   # 1st Convolutional block in the encoder network
#   encoder1 = Convolution2D(filters=64, kernel_size=8,
#   padding='same',
#   strides=strides)(input_layer)
#   encoder1 = LeakyReLU(alpha=leakyrelu_alpha)(encoder1)
#   # 2nd Convolutional block in the encoder network
#   encoder2 = Convolution2D(filters=128, kernel_size=6,
#   padding='same',
#   strides=strides)(encoder1)
#   encoder2 = BatchNormalization()(encoder2)
#   encoder2 = LeakyReLU(alpha=leakyrelu_alpha)(encoder2)
#   # 3rd Convolutional block in the encoder network
#   encoder3 = Convolution2D(filters=256, kernel_size=4,
#   padding='same',
#   strides=strides)(encoder2)
#   encoder3 = BatchNormalization()(encoder3)
#   encoder3 = LeakyReLU(alpha=leakyrelu_alpha)(encoder3)

#   # 6th Upsampling Convolutional block in the decoder network
#   decoder6 = UpSampling2D(size=upsampling_size)(encoder3)
#   decoder6 = Convolution2D(filters=128, kernel_size=6,
#   padding='same')(decoder6)
#   decoder6 = BatchNormalization()(decoder6)
#   decoder6 = concatenate([decoder6, encoder2])
#   decoder6 = LeakyReLU(alpha=leakyrelu_alpha)(decoder6)
#   # 7th Upsampling Convolutional block in the decoder network
#   decoder7 = UpSampling2D(size=upsampling_size)(decoder6)
#   decoder7 = Convolution2D(filters=64, kernel_size=6,
#   padding='same')(decoder7)
#   decoder7 = BatchNormalization()(decoder7)
#   decoder7 = concatenate([decoder7, encoder1])
#   decoder7 = LeakyReLU(alpha=leakyrelu_alpha)(decoder7)


#   # Last Convolutional layer
#   decoder8 = UpSampling2D(size=(2, 1))(decoder7)
#   decoder8 = Convolution2D(filters=output_channels,
#   kernel_size=8, padding='same')(decoder8)
#   decoder8 = Activation('softmax')(decoder8)

#   model = Model(inputs=[input_layer], outputs=[decoder8])

#   return model

# model = build_unet_generator(needed_labels)
# model.summary()

# %%
def get_model(needed_labels): # Deeper Autoencoder
    model = Sequential()
  
    model.add(Conv2D(32, (5, 5), strides=2, padding='same', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(64, (5, 5), strides=2, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(128, (3, 3), strides=2, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(128, (3, 3), strides=2, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(256, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(256, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(UpSampling2D((2, 2)))
    model.add(Conv2D(256, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(UpSampling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(UpSampling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(UpSampling2D((2, 1)))
    model.add(Conv2D(32, (5, 5), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    
    model.add(Conv2D(len(needed_labels), (5, 5), activation='softmax', padding='same'))

    return model

model = get_model(needed_labels)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 72, 32)        2432
#
#  batch_normalization (BatchN  (None, 40, 72, 32)       128
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 40, 72, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 20, 36, 64)        51264
#
#  batch_normalization_1 (Batc  (None, 20, 36, 64)       256
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 20, 36, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 10, 18, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 10, 18, 128)      512
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 10, 18, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 5, 9, 128)         147584
#
#  batch_normalization_3 (Batc  (None, 5, 9, 128)        512
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 5, 9, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 5, 9, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 5, 9, 256)        1024
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 5, 9, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 5, 9, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 5, 9, 256)        1024
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 5, 9, 256)         0
#
#  up_sampling2d (UpSampling2D  (None, 10, 18, 256)      0
#  )
#
#  conv2d_6 (Conv2D)           (None, 10, 18, 256)       590080
#
#  batch_normalization_6 (Batc  (None, 10, 18, 256)      1024
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 10, 18, 256)       0
#
#  up_sampling2d_1 (UpSampling  (None, 20, 36, 256)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 20, 36, 128)       295040
#
#  batch_normalization_7 (Batc  (None, 20, 36, 128)      512
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 20, 36, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 20, 36, 128)       147584
#
#  batch_normalization_8 (Batc  (None, 20, 36, 128)      512
#  hNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 20, 36, 128)       0
#
#  up_sampling2d_2 (UpSampling  (None, 40, 72, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 40, 72, 64)        73792
#
#  batch_normalization_9 (Batc  (None, 40, 72, 64)       256
#  hNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 40, 72, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 40, 72, 32)        18464
#
#  batch_normalization_10 (Bat  (None, 40, 72, 32)       128
#  chNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 40, 72, 32)        0
#
#  up_sampling2d_3 (UpSampling  (None, 80, 72, 32)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 80, 72, 32)        25632
#
#  batch_normalization_11 (Bat  (None, 80, 72, 32)       128
#  chNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 80, 72, 32)        0
#
#  conv2d_12 (Conv2D)          (None, 80, 72, 3)         2403
#
# =================================================================
# Total params: 2,319,395
# Trainable params: 2,316,387
# Non-trainable params: 3,008
# _________________________________________________________________

# %%
# Checking if the model can run at real time on current GPU at specifies fps

from time import time
fps = 30

x = np.random.random(input_shape)
start = time()

for i in range(fps):
    out = model.predict(np.array([x]), verbose = 0) # predict silently

print(time() - start)
# Out:
# 10.066767454147339

# %%
from keras.optimizers import Nadam
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from time import time

optimizer = Nadam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, schedule_decay=0.004)
tensorboard = TensorBoard(log_dir = bev_folder+"logs/{}".format(time()))
early_stopping = EarlyStopping(monitor='val_loss', patience=30)

filepath = bev_folder+"Saved Models/model-{epoch:02d}-{val_loss:.5f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False)
callbacks_list = [checkpoint, tensorboard]

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true) # float32
    y_pred_f = K.flatten(y_pred) # float32
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_multilabel(y_true, y_pred, numLabels=len(needed_labels)):
    dice=0
    for index in range(0, numLabels):                                          
        dice -= dice_coef(y_true[:, :, :, index], y_pred[:, :, :, index])
    return numLabels + dice

def ssim_loss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))

def custom_loss(y_true, y_pred):
    return dice_coef_multilabel(y_true, y_pred) + 5*ssim_loss(y_true, y_pred)

# %%
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.compile(optimizer='adam', loss=custom_loss, metrics=['categorical_accuracy'])

# %%
NUM_EPOCHS = 100

history = model.fit(train_generator, epochs=NUM_EPOCHS, 
                    shuffle=True, callbacks=callbacks_list, 
                    validation_data= val_generator)
# Out:
# Epoch 1/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.9993 - categorical_accuracy: 0.9079
# Epoch 1: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-01-1.32910.hdf5
# 1281/1281 [==============================] - 204s 152ms/step - loss: 1.9993 - categorical_accuracy: 0.9079 - val_loss: 1.3291 - val_categorical_accuracy: 0.9260
# Epoch 2/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.5867 - categorical_accuracy: 0.9432
# Epoch 2: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-02-1.17920.hdf5
# 1281/1281 [==============================] - 196s 153ms/step - loss: 1.5867 - categorical_accuracy: 0.9432 - val_loss: 1.1792 - val_categorical_accuracy: 0.9423
# Epoch 3/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.5023 - categorical_accuracy: 0.9486
# Epoch 3: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-03-1.36194.hdf5
# 1281/1281 [==============================] - 195s 152ms/step - loss: 1.5023 - categorical_accuracy: 0.9486 - val_loss: 1.3619 - val_categorical_accuracy: 0.9413
# Epoch 4/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.4523 - categorical_accuracy: 0.9518
# Epoch 4: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-04-1.05852.hdf5
# 1281/1281 [==============================] - 194s 152ms/step - loss: 1.4523 - categorical_accuracy: 0.9518 - val_loss: 1.0585 - val_categorical_accuracy: 0.9514
# Epoch 5/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.4206 - categorical_accuracy: 0.9535
# Epoch 5: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-05-1.04403.hdf5
# 1281/1281 [==============================] - 195s 152ms/step - loss: 1.4206 - categorical_accuracy: 0.9535 - val_loss: 1.0440 - val_categorical_accuracy: 0.9530
# Epoch 6/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.3894 - categorical_accuracy: 0.9554
# Epoch 6: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-06-1.09455.hdf5
# 1281/1281 [==============================] - 194s 152ms/step - loss: 1.3894 - categorical_accuracy: 0.9554 - val_loss: 1.0946 - val_categorical_accuracy: 0.9525
# Epoch 7/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.3683 - categorical_accuracy: 0.9565
# Epoch 7: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-07-1.03805.hdf5
# 1281/1281 [==============================] - 193s 151ms/step - loss: 1.3683 - categorical_accuracy: 0.9565 - val_loss: 1.0381 - val_categorical_accuracy: 0.9537
# Epoch 8/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.3461 - categorical_accuracy: 0.9577
# Epoch 8: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-08-1.02377.hdf5
# 1281/1281 [==============================] - 194s 151ms/step - loss: 1.3461 - categorical_accuracy: 0.9577 - val_loss: 1.0238 - val_categorical_accuracy: 0.9563
# Epoch 9/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.3148 - categorical_accuracy: 0.9583
# Epoch 9: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-09-0.99508.hdf5
# 1281/1281 [==============================] - 193s 151ms/step - loss: 1.3148 - categorical_accuracy: 0.9583 - val_loss: 0.9951 - val_categorical_accuracy: 0.9546
# Epoch 10/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.2488 - categorical_accuracy: 0.9589
# Epoch 10: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-10-0.96960.hdf5
# 1281/1281 [==============================] - 193s 151ms/step - loss: 1.2488 - categorical_accuracy: 0.9589 - val_loss: 0.9696 - val_categorical_accuracy: 0.9536
# Epoch 11/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.2015 - categorical_accuracy: 0.9599
# Epoch 11: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-11-0.96363.hdf5
# 1281/1281 [==============================] - 193s 150ms/step - loss: 1.2015 - categorical_accuracy: 0.9599 - val_loss: 0.9636 - val_categorical_accuracy: 0.9572
# Epoch 12/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.1746 - categorical_accuracy: 0.9608
# Epoch 12: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-12-0.94835.hdf5
# 1281/1281 [==============================] - 194s 152ms/step - loss: 1.1746 - categorical_accuracy: 0.9608 - val_loss: 0.9483 - val_categorical_accuracy: 0.9568
# Epoch 13/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.1579 - categorical_accuracy: 0.9612
# Epoch 13: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-13-0.93943.hdf5
# 1281/1281 [==============================] - 193s 151ms/step - loss: 1.1579 - categorical_accuracy: 0.9612 - val_loss: 0.9394 - val_categorical_accuracy: 0.9564
# Epoch 14/100
# 1281/1281 [==============================] - ETA: 0s - loss: 1.1415 - categorical_accuracy: 0.9619
# Epoch 14: saving model to ./drive/My Drive/Autonomous Driving/bev_generation_mapping/Saved Models/model-14-0.93380.hdf5
# 1281/1281 [==============================] - 193s 151ms/step - loss: 1.1415 - categorical_accuracy: 0.9619 - val_loss: 0.9338 - val_categorical_accuracy: 0.9581
# Epoch 15/100
#  113/1281 [=>............................] - ETA: 2:30 - loss: 1.1225 - categorical_accuracy: 0.9630
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-290-5d464f532a27> in <cell line: 3>()
#       1 NUM_EPOCHS = 100
#       2
# ----> 3 history = model.fit(train_generator, epochs=NUM_EPOCHS,
#       4                     shuffle=True, callbacks=callbacks_list,
#       5                     validation_data= val_generator)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Testing the model

# %%
from keras.models import load_model

model = load_model(bev_folder + 'Saved Models/model-14-0.93380.hdf5', compile=False)
columns = 3
rows = 1

# %%
fig=plt.figure()
for i in range(1, columns*rows + 1):
    img = X[i-1]
    fig.add_subplot(rows, columns, i)
    # plt.imshow(categorical_to_img(img), cmap='gist_stern', vmin=0, vmax=len(needed_labels) - 1)
    plot_rgb(categorical_to_img(img))
plt.show()
fig.savefig('orig.png', bbox_inches='tight')

# %%
fig=plt.figure()
for i in range(1, columns*rows + 1):
    img = X[i-1]
    pred = model.predict(np.array([img]))
    fig.add_subplot(rows, columns, i)
    # plt.imshow(np.rot90(categorical_to_img(pred[0]), 3), cmap='gist_stern', vmin=0, vmax=len(needed_labels)-1)
    plot_rgb(categorical_to_img(pred[0]))
plt.show()
fig.savefig('pred.png', bbox_inches='tight')
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
fig=plt.figure()
for i in range(1, columns*rows + 1):
    img = y[i-1]
    fig.add_subplot(rows, columns, i)
    # plt.imshow(np.rot90(categorical_to_img(img), 3), cmap='gist_stern', vmin=0, vmax=len(needed_labels)-1)
    plot_rgb(categorical_to_img(img))
plt.show()
fig.savefig('actual.png', bbox_inches='tight')

# %%
## Use this and play video on your own pc by loading the numpy array.

imgs = []

for i in range(len(X)):
    img = X[i]
    pred = model.predict(np.array([img]))
    img = np.rot90(categorical_to_img(pred[0]), 3)
    imgs.append(img.astype('uint8'))

np.save('output7', np.array(imgs))
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
img = X[0]
print('INPUT (Front):', img.shape)
img = y[0]
print('OUTPUT (Top):', img.shape)
# Out:
# INPUT (Front): (80, 144, 3)
# OUTPUT (Top): (80, 72, 3)

# %%
import cv2

orig = cv2.cvtColor(cv2.imread('orig.png'), cv2.COLOR_BGR2RGB)
pred = cv2.cvtColor(cv2.imread('pred.png'), cv2.COLOR_BGR2RGB)
actual = cv2.cvtColor(cv2.imread('actual.png'), cv2.COLOR_BGR2RGB)

full = cv2.vconcat([orig, pred, actual])
plt.axis('off')
plt.imshow(full)
plt.show()
